# %%
import numpy as np
import pandas as pd

# %%
energy = pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)

# %%
energy.head()
# Out:
#    Unnamed: 0      Unnamed: 1      Unnamed: 2 Petajoules Gigajoules  \
# 0         NaN     Afghanistan     Afghanistan        321         10
# 1         NaN         Albania         Albania        102         35
# 2         NaN         Algeria         Algeria       1959         51
# 3         NaN  American Samoa  American Samoa        ...        ...
# 4         NaN         Andorra         Andorra          9        121
#
#             %
# 0   78.669280
# 1  100.000000
# 2    0.551010
# 3    0.641026
# 4   88.695650

# %%
energy.columns[0:2]
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1'], dtype='object')

# %%
energy.drop(energy.columns[0:2],axis = 1,inplace =True)

# %%
energy.rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'},inplace=True)

# %%
energy['Energy Supply'] *=1000000

# %%
energy= energy.replace('\.+',np.nan,regex =True)

# %%
energy['Country'] = energy['Country'].replace("Republic of Korea", "South Korea")
energy['Country'] = energy['Country'].replace("United States of America", "United States")
energy['Country'] = energy['Country'].replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom")
energy['Country'] = energy['Country'].replace("China, Hong Kong Special Administrative Region", "Hong Kong")

# %%
energy['Country'] = energy['Country'].str.replace(" \(.*\)","")

# %%
energy['Country']=energy['Country'].apply(lambda x: x.strip('0123456789'))

# %%
energy.iloc[214]['Country']
# Out:
# 'United Kingdom of Great Britain and Northern Ireland'

# %%
energy['Country'] = energy['Country'].replace("Republic of Korea", "South Korea")
energy['Country'] = energy['Country'].replace("United States of America", "United States")
energy['Country'] = energy['Country'].replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom")
energy['Country'] = energy['Country'].replace("China, Hong Kong Special Administrative Region", "Hong Kong")

# %%
energy.set_index('Country',inplace=True)

# %%
len(energy.index)
# Out:
# 227

# %%
GDP = pd.read_csv('world_bank.csv',skiprows=4)
GDP
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
di={"Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"
}
GDP.replace({'Country Name':di},inplace=True)

# %%
GDP['Country Name'].head(100)
# Out:
# 0                                        Aruba
# 1                                      Andorra
# 2                                  Afghanistan
# 3                                       Angola
# 4                                      Albania
# 5                                   Arab World
# 6                         United Arab Emirates
# 7                                    Argentina
# 8                                      Armenia
# 9                               American Samoa
# 10                         Antigua and Barbuda
# 11                                   Australia
# 12                                     Austria
# 13                                  Azerbaijan
# 14                                     Burundi
# 15                                     Belgium
# 16                                       Benin
# 17                                Burkina Faso
# 18                                  Bangladesh
# 19                                    Bulgaria
# ...

# %%
GDP.rename(columns={'Country Name':'Country'},inplace=True)

# %%
GDP
# Out:
#                                                Country Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
GDP=GDP[['Country','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']]
GDP
# Out:
#                                                Country          2006  \
# 0                                                Aruba           NaN
# 1                                              Andorra  4.018196e+09
# 2                                          Afghanistan  1.030523e+10
# 3                                               Angola  5.581103e+10
# 4                                              Albania  9.771760e+09
# 5                                           Arab World  1.763824e+12
# 6                                 United Arab Emirates  2.789489e+11
# 7                                            Argentina  3.788140e+11
# 8                                              Armenia  8.679746e+09
# 9                                       American Samoa           NaN
# 10                                 Antigua and Barbuda  1.268714e+09
# 11                                           Australia  1.021939e+12
# 12                                             Austria  3.782096e+11
# ...

# %%
GDP.set_index('Country',inplace=True)

# %%
GDP
# Out:
#                                                            2006          2007  \
# Country
# Aruba                                                       NaN           NaN
# Andorra                                            4.018196e+09  4.021331e+09
# Afghanistan                                        1.030523e+10  1.172119e+10
# Angola                                             5.581103e+10  6.842044e+10
# Albania                                            9.771760e+09  1.034829e+10
# Arab World                                         1.763824e+12  1.863481e+12
# United Arab Emirates                               2.789489e+11  2.878318e+11
# Argentina                                          3.788140e+11  4.089887e+11
# Armenia                                            8.679746e+09  9.873142e+09
# American Samoa                                              NaN           NaN
# Antigua and Barbuda                                1.268714e+09  1.389229e+09
# ...

# %%
len(GDP.index)
# Out:
# 264

# %%
ScimEn = pd.read_excel('scimagojr-3.xlsx')

# %%
ScimEn=ScimEn[0:16]

# %%
ScimEn
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
ScimEn.set_index('Country',inplace=True)

# %%
ScimEn
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
len(ScimEn.index)
# Out:
# 16

# %%
df = pd.merge(GDP,energy,how = 'inner',left_index=True,right_index=True)

# %%
len(df)
# Out:
# 186

# %%
final_df = pd.merge(df,ScimEn,how= 'inner',left_index=True,right_index=True)

# %%
len(final_df)
# Out:
# 15

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, Australia to United States
# Data columns (total 20 columns):
# 2006                        15 non-null float64
# 2007                        15 non-null float64
# 2008                        15 non-null float64
# 2009                        15 non-null float64
# 2010                        15 non-null float64
# 2011                        15 non-null float64
# 2012                        15 non-null float64
# 2013                        15 non-null float64
# 2014                        15 non-null float64
# 2015                        14 non-null float64
# Energy Supply               15 non-null float64
# Energy Supply per Capita    15 non-null float64
# % Renewable                 15 non-null float64
# Rank                        15 non-null int64
# Documents                   15 non-null int64
# Citable documents           15 non-null int64
# Citations                   15 non-null int64
# ...

# %%
# %%HTML
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>
# Out:
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>

# %%
len(final_df)
# Out:
# 15

# %%
#2

# %%
en1 = pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)

# %%
en1.head()
# Out:
#    Unnamed: 0      Unnamed: 1      Unnamed: 2 Petajoules Gigajoules  \
# 0         NaN     Afghanistan     Afghanistan        321         10
# 1         NaN         Albania         Albania        102         35
# 2         NaN         Algeria         Algeria       1959         51
# 3         NaN  American Samoa  American Samoa        ...        ...
# 4         NaN         Andorra         Andorra          9        121
#
#             %
# 0   78.669280
# 1  100.000000
# 2    0.551010
# 3    0.641026
# 4   88.695650

# %%
en1.rename(columns={'Unnamed: 2':'Country'},inplace=True)
en1.set_index('Country',inplace=True)

# %%
en1.head()
# Out:
#                 Unnamed: 0      Unnamed: 1 Petajoules Gigajoules           %
# Country
# Afghanistan            NaN     Afghanistan        321         10   78.669280
# Albania                NaN         Albania        102         35  100.000000
# Algeria                NaN         Algeria       1959         51    0.551010
# American Samoa         NaN  American Samoa        ...        ...    0.641026
# Andorra                NaN         Andorra          9        121   88.695650

# %%
len(en1)
# Out:
# 227

# %%
GD1 = pd.read_csv('world_bank.csv',skiprows=4)

# %%
GD1.rename(columns={'Country Name':'Country'},inplace=True)
GD1.set_index('Country',inplace=True)
GD1.head()
# Out:
#             Country Code                            Indicator Name  \
# Country
# Aruba                ABW  GDP at market prices (constant 2010 US$)
# Andorra              AND  GDP at market prices (constant 2010 US$)
# Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# Angola               AGO  GDP at market prices (constant 2010 US$)
# Albania              ALB  GDP at market prices (constant 2010 US$)
#
#              Indicator Code  1960  1961  1962  1963  1964  1965  1966  \
# Country
# Aruba        NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra      NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola       NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania      NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                  ...               2006          2007          2008  \
# Country          ...
# ...

# %%
len(GD1)
# Out:
# 264

# %%
Sc1 = pd.read_excel('scimagojr-3.xlsx')

# %%
Sc1.set_index('Country',inplace=True)

# %%
Sc1.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57

# %%
len(Sc1)
# Out:
# 191

# %%
union = pd.merge(pd.merge(en1,GD1,how='outer',left_index=True,right_index=True),Sc1,how='outer',left_index=True,right_index=True)

# %%
len(union)
# Out:
# 343

# %%
len(pd.merge(energy, GDP, on='Country', how='outer'))
# Out:
# 305

# %%
len(energy)
# Out:
# 227

# %%
len(ScimEn)
# Out:
# 16

# %%
intersect = pd.merge(pd.merge(en1,GD1,left_index=True,right_index=True),Sc1,left_index=True,right_index=True)

# %%
len(intersect)
# Out:
# 140

# %%
len(union)-len(intersect)
# Out:
# 203

# %%
 df = pd.merge(ScimEn, energy, how = 'inner', left_on = 'Country', right_on='Country')
final_df = pd.merge(df,GDP, how = 'inner', left_on = 'Country', right_on='Country')

# %%
len(final_df)
# Out:
# 15

# %%
df2 = pd.merge(ScimEn, energy, how = 'outer', left_on = 'Country', right_on='Country')
final_df2 = pd.merge(df2,GDP, how = 'outer', left_on = 'Country', right_on='Country')

# %%
len(final_df2)
# Out:
# 306
